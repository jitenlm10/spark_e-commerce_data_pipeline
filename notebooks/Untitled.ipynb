# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
# 1. Initialize a LOCAL Spark session just for Jupyter
spark = SparkSession.builder \
    .appName("View_Cleaned_Data") \
    .master("local[*]") \
    .getOrCreate()

# 2. Read the Parquet folder 
# (Jupyter maps your project folder to /home/jovyan/work)
events_clean_df = spark.read.parquet("/home/jovyan/work/cleaned/events_clean")

user_1_events = events_clean_df.filter(col("user_id") == 7).orderBy("timestamp")

# 4. Print the total number of events for this user
print(f"--- TOTAL EVENTS FOR USER 1: {user_1_events.count()} ---")

# 5. Show the actual data
print("\n--- TIMELINE FOR USER 1 ---")
user_1_events.show(truncate=False)

# row_count = events_clean_df.count()
# print(f"--- TOTAL ROWS: {row_count} ---")

# # 3. Print the schema to verify our data types and our Catalog join
# print("--- SCHEMA ---")
# events_clean_df.printSchema()

# # 4. Show the top 10 rows of the actual data
# print("--- TOP 200 ROWS ---")
# events_clean_df.show(200, truncate=False)
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[6], line 7
#       2 from pyspark.sql.functions import col
#       3 # 1. Initialize a LOCAL Spark session just for Jupyter
#       4 spark = SparkSession.builder \
#       5     .appName("View_Cleaned_Data") \
#       6     .master("local[*]") \
# ----> 7     .getOrCreate()
#       9 # 2. Read the Parquet folder
#      10 # (Jupyter maps your project folder to /home/jovyan/work)
#      11 events_clean_df = spark.read.parquet("/home/jovyan/work/cleaned/events_clean")
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
from pyspark.sql import SparkSession

# 1. Initialize a LOCAL Spark session just for Jupyter
spark = SparkSession.builder \
    .appName("View_Sessionized_Data") \
    .master("local[*]") \
    .getOrCreate()

# 2. Read the Sessionized Parquet folder
events_sessions_df = spark.read.parquet("/home/jovyan/work/output/events_with_sessions")

# 3. Print the total row count
row_count = events_sessions_df.count()
print(f"--- TOTAL ROWS: {row_count} ---")

# 4. Print the schema to verify our new session_id column
print("\n--- SCHEMA ---")
events_sessions_df.printSchema()

# 5. Show the top 20 rows, ordered chronologically per user to visually verify sessions
print("\n--- TOP 20 ROWS (Chronological by User) ---")
events_sessions_df.orderBy("user_id", "timestamp").show(200, truncate=False)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("View_Funnel").master("local[*]").getOrCreate()
funnel_df = spark.read.parquet("/home/jovyan/work/output/funnel_metrics")

print("--- FUNNEL CONVERSION RATES ---")
# Sorting by highest total views to see the most popular categories first
funnel_df.orderBy(col("category").desc()).show(20, truncate=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

print(sys.executable)

# Read parquet directly with pandas
df = pd.read_parquet("../output/anomalies_only")

# Aggregate by category
pdf = (
    df.groupby("category")[["total_views", "total_carts", "total_purchases"]]
      .sum()
      .sort_values("total_views", ascending=False)
)

# Rename columns for cleaner legend
pdf.columns = ["1_Views", "2_Carts", "3_Purchases"]

# Plot
ax = pdf.plot(kind="bar", figsize=(14, 7), width=0.8)

plt.title("E-commerce Funnel Conversion by Product Category", fontsize=16, fontweight="bold", pad=20)
plt.xlabel("Product Category", fontsize=14, fontweight="bold")
plt.ylabel("Total Count of Events", fontsize=14, fontweight="bold")
plt.xticks(rotation=45, ha="right", fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.legend(title="Funnel Stage", fontsize=12, title_fontsize=12)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

df["date"] = pd.to_datetime(df["date"])

plt.figure(figsize=(12,5))

plt.scatter(
    df["date"],
    df["overall_conversion_rate"]
)

plt.title("Detected Conversion Anomalies")
plt.xlabel("Date")
plt.ylabel("Conversion Rate")

plt.xticks(rotation=45)

plt.show()

# %%
import sys
import pandas as pd

print(sys.executable)
print(pd.__version__)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("SparkNotebook") \
    .master("local[*]") \
    .getOrCreate()

df = spark.read.parquet("../output/anomalies_only")

df.show(20, truncate=False)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# Cell In[1], line 8
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("SparkNotebook") \
#       5     .master("local[*]") \
#       6     .getOrCreate()
# ----> 8 df = spark.read.parquet("../output/anomalies_only")
#      10 df.show(20, truncate=False)
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\sql\readwriter.py:642, in DataFrameReader.parquet(self, *paths, **options)
#     631 int96RebaseMode = options.get("int96RebaseMode", None)
#     632 self._set_opts(
#     633     mergeSchema=mergeSchema,
#     634     pathGlobFilter=pathGlobFilter,
#    (...)    639     int96RebaseMode=int96RebaseMode,
#     640 )
# --> 642 return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\errors\exceptions\captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# UnsupportedOperationException: getSubject is not supported

# %%
import os

os.environ["PYSPARK_SUBMIT_ARGS"] = (
    '--conf "spark.driver.extraJavaOptions=-Djava.security.manager=allow" '
    '--conf "spark.executor.extraJavaOptions=-Djava.security.manager=allow" '
    'pyspark-shell'
)

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("SparkNotebook") \
    .master("local[*]") \
    .config("spark.driver.host", "127.0.0.1") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .getOrCreate()

print("Spark started")
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[1], line 16
#       3 os.environ["PYSPARK_SUBMIT_ARGS"] = (
#       4     '--conf "spark.driver.extraJavaOptions=-Djava.security.manager=allow" '
#       5     '--conf "spark.executor.extraJavaOptions=-Djava.security.manager=allow" '
#       6     'pyspark-shell'
#       7 )
#       9 from pyspark.sql import SparkSession
#      11 spark = SparkSession.builder \
#      12     .appName("SparkNotebook") \
#      13     .master("local[*]") \
#      14     .config("spark.driver.host", "127.0.0.1") \
#      15     .config("spark.driver.bindAddress", "127.0.0.1") \
# ---> 16     .getOrCreate()
#      18 print("Spark started")
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pyspark\java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_parquet("../output/anomalies_only")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_parquet("../output/anomalies_only")
#       4 df.head()
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File c:\Users\suyas\OneDrive\Desktop\spark-ecommerce\venv\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.
